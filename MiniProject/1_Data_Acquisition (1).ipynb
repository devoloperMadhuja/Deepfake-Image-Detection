# %%
# Cell 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cell 2: Configure Kaggle API and Download Dataset
import os
from google.colab import files

print("--- Step 1: Configuring Kaggle API ---")
# Check if the Kaggle API key already exists
if not os.path.exists("/root/.kaggle/kaggle.json"):
    print("Please upload your kaggle.json file:")
    uploaded = files.upload()
    if uploaded:
        uploaded_filename = list(uploaded.keys())[0]
        # Create the .kaggle directory and move the API key
        # !mkdir -p ~/.kaggle
        # !mv "{uploaded_filename}" /root/.kaggle/kaggle.json
        # !chmod 600 /root/.kaggle/kaggle.json
        print("\n✅ Kaggle API key configured successfully.")
    else:
        raise ValueError("Upload cancelled or failed. Please run the cell again.")
else:
    print("Kaggle API key already exists.")

print("\n--- Step 2: Downloading Dataset ZIP to Google Drive ---")

# --- USER: UPDATE THIS PATH ---
# This is the folder in your Google Drive where the ZIP will be saved.
DOWNLOAD_PATH = '/content/drive/MyDrive/Mini Project'
os.makedirs(DOWNLOAD_PATH, exist_ok=True)
print(f"Data will be downloaded to: {DOWNLOAD_PATH}")

# Download the dataset from Kaggle without unzipping it
# !kaggle datasets download -d xhlulu/140k-real-and-fake-faces -p "{DOWNLOAD_PATH}"

print("\n✅ ZIP file downloaded successfully!")
print("You can now proceed to the training notebook.")
# Out:
# --- Step 1: Configuring Kaggle API ---
# Please upload your kaggle.json file:
#      <input type="file" id="files-5d5139f9-e811-44c1-bf97-fb7a3d333a00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d5139f9-e811-44c1-bf97-fb7a3d333a00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
